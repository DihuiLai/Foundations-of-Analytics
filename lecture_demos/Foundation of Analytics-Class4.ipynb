# %% [markdown]
# ## Linear Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
X=2*np.random.randn(1, 5000)
Y=.3*X+10+np.random.randn(1, 5000)

# %%
X_pd=pd.DataFrame(X.T)
Y_pd=pd.DataFrame(Y.T)

# %%
import statsmodels.api as sm
X_pd = sm.add_constant(X_pd)

# %%
X_pd
# Out:
#       const         0
# 0       1.0  0.182053
# 1       1.0 -2.310026
# 2       1.0  2.539475
# 3       1.0  1.596383
# 4       1.0 -4.528406
# 5       1.0  0.675234
# 6       1.0  0.431924
# 7       1.0  0.391633
# 8       1.0 -1.372963
# 9       1.0 -0.279360
# 10      1.0  0.973272
# 11      1.0 -1.110492
# 12      1.0 -0.604805
# 13      1.0 -0.228651
# 14      1.0  1.157483
# 15      1.0  0.958270
# 16      1.0 -2.333818
# 17      1.0  1.179801
# 18      1.0 -1.419045
# 19      1.0  0.556909
# 20      1.0  1.517025
# 21      1.0 -0.242886
# 22      1.0  0.212224
# 23      1.0 -2.641330
# 24      1.0  0.371701
# 25      1.0 -0.375920
# 26      1.0 -1.362600
# 27      1.0 -0.565403
# 28      1.0  5.846529
# 29      1.0 -0.506876
# ...     ...       ...
# 4970    1.0  2.473411
# 4971    1.0  1.080275
# 4972    1.0 -2.601445
# 4973    1.0 -1.436560
# 4974    1.0 -0.886618
# 4975    1.0 -1.177935
# 4976    1.0  0.234421
# 4977    1.0 -1.642181
# 4978    1.0 -0.091246
# 4979    1.0 -0.959851
# 4980    1.0 -1.242668
# 4981    1.0 -2.813287
# 4982    1.0  1.676341
# 4983    1.0 -0.061746
# 4984    1.0 -0.419368
# 4985    1.0 -3.613016
# 4986    1.0 -0.609151
# 4987    1.0  3.658453
# 4988    1.0 -2.927974
# 4989    1.0 -0.055600
# 4990    1.0 -1.906708
# 4991    1.0 -0.328820
# 4992    1.0 -0.552770
# 4993    1.0 -0.759007
# 4994    1.0 -1.000422
# 4995    1.0 -3.006355
# 4996    1.0  3.196368
# 4997    1.0 -4.019892
# 4998    1.0  3.636852
# 4999    1.0 -0.145957
#
# [5000 rows x 2 columns]

# %%
# Instantiate a gamma family model with the default link function.
gaussian_model = sm.GLM(Y_pd, X_pd, family=sm.families.Gaussian())

gaussian_model_results = gaussian_model.fit()

print(gaussian_model_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      0   No. Observations:                 5000
# Model:                            GLM   Df Residuals:                     4998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                          1.0102
# Method:                          IRLS   Log-Likelihood:                -7119.0
# Date:                Sat, 17 Aug 2019   Deviance:                       5048.9
# Time:                        15:30:42   Pearson chi2:                 5.05e+03
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.9982      0.014    703.390      0.000       9.970      10.026
# 0              0.3028      0.007     42.371      0.000       0.289       0.317
# ==============================================================================

# %%
reg = LinearRegression().fit(X.T, Y.T)
print [reg.coef_, reg.intercept_]
# Out:
# [array([[0.30283062]]), array([9.99822294])]
