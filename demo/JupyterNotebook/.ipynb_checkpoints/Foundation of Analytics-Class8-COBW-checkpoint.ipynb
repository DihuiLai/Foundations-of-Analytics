# %% [markdown]
# ### New package installation
# ```pip install tensorflow_datasets```
#
# ```pip install ipywidgets```
#
# ```pip install nltk```

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import tensorflow_datasets as tfds
tfds.disable_progress_bar()
(train_data, test_data), info = tfds.load(
    'imdb_reviews/subwords8k', 
    split = (tfds.Split.TRAIN, tfds.Split.TEST), 
    with_info=True, as_supervised=True)

# %%
file = open("Data/J. K. Rowling - Harry Potter 1 - Sorcerer's Stone",'r')
raw_data_1 = file.read()
file.close()

# %%
from nltk.tokenize import word_tokenize, wordpunct_tokenize

from nltk.corpus import stopwords 
import nltk 
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
stop_words = set(stopwords.words('english')) 
word_tokens=wordpunct_tokenize(raw_data_1)  
word_tokens = [w.lower() for w in word_tokens if not w in stop_words] 
word_tokens = [w.lower() for w in word_tokens if w.isalpha()]

# %%
word_tokens
# Out:
# ['harry',
#  'potter',
#  'sorcerer',
#  'stone',
#  'chapter',
#  'one',
#  'the',
#  'boy',
#  'who',
#  'lived',
#  'mr',
#  'mrs',
#  'dursley',
#  'number',
#  'four',
#  'privet',
#  'drive',
#  'proud',
#  'say',
#  'perfectly',
#  'normal',
#  'thank',
#  'much',
#  'they',
#  'last',
#  'people',
#  'expect',
#  'involved',
#  'anything',
#  'strange',
#  'mysterious',
#  'hold',
#  'nonsense',
#  'mr',
#  'dursley',
#  'director',
#  'firm',
#  'called',
#  'grunnings',
#  'made',
#  'drills',
#  'he',
#  'big',
#  'beefy',
#  'man',
#  'hardly',
#  'neck',
#  'although',
#  'large',
#  'mustache',
#  'mrs',
#  'dursley',
#  'thin',
#  'blonde',
#  'nearly',
#  'twice',
#  'usual',
#  'amount',
#  'neck',
#  'came',
#  'useful',
#  'spent',
#  'much',
#  'time',
#  'craning',
#  'garden',
#  'fences',
#  'spying',
#  'neighbors',
#  'the',
#  'dursleys',
#  'small',
#  'son',
#  'called',
#  'dudley',
#  'opinion',
#  'finer',
#  'boy',
#  'anywhere',
#  'the',
#  'dursleys',
#  'everything',
#  'wanted',
#  'also',
#  'secret',
#  'greatest',
#  'fear',
#  'somebody',
#  'would',
#  'discover',
#  'they',
#  'think',
#  'could',
#  'bear',
#  'anyone',
#  'found',
#  'potters',
#  'mrs',
#  'potter',
#  'mrs',
#  'dursley',
#  'sister',
#  'met',
#  'several',
#  'years',
#  'fact',
#  'mrs',
#  'dursley',
#  'pretended',
#  'sister',
#  'sister',
#  'good',
#  'nothing',
#  'husband',
#  'undursleyish',
#  'possible',
#  'the',
#  'dursleys',
#  'shuddered',
#  'think',
#  'neighbors',
#  'would',
#  'say',
#  'potters',
#  'arrived',
#  'street',
#  'the',
#  'dursleys',
#  'knew',
#  'potters',
#  'small',
#  'son',
#  'never',
#  'even',
#  'seen',
#  'this',
#  'boy',
#  'another',
#  'good',
#  'reason',
#  'keeping',
#  'potters',
#  'away',
#  'want',
#  'dudley',
#  'mixing',
#  'child',
#  'like',
#  'when',
#  'mr',
#  'mrs',
#  'dursley',
#  'woke',
#  'dull',
#  'gray',
#  'tuesday',
#  'story',
#  'starts',
#  'nothing',
#  'cloudy',
#  'sky',
#  'outside',
#  'suggest',
#  'strange',
#  'mysterious',
#  'things',
#  'would',
#  'soon',
#  'happening',
#  'country',
#  'mr',
#  'dursley',
#  'hummed',
#  'picked',
#  'boring',
#  'tie',
#  'work',
#  'mrs',
#  'dursley',
#  'gossiped',
#  'away',
#  'happily',
#  'wrestled',
#  'screaming',
#  'dudley',
#  'high',
#  'chair',
#  'none',
#  'noticed',
#  'large',
#  'tawny',
#  'owl',
#  'flutter',
#  'past',
#  'window',
#  'at',
#  'half',
#  'past',
#  'eight',
#  'mr',
#  'dursley',
#  'picked',
#  'briefcase',
#  'pecked',
#  'mrs',
#  'dursley',
#  'cheek',
#  'tried',
#  'kiss',
#  'dudley',
#  'good',
#  'bye',
#  'missed',
#  'dudley',
#  'tantrum',
#  'throwing',
#  'cereal',
#  'walls',
#  'little',
#  'tyke',
#  'chortled',
#  'mr',
#  'dursley',
#  'left',
#  'house',
#  'he',
#  'got',
#  'car',
#  'backed',
#  'number',
#  'four',
#  'drive',
#  'it',
#  'corner',
#  'street',
#  'noticed',
#  'first',
#  'sign',
#  'something',
#  'peculiar',
#  'cat',
#  'reading',
#  'map',
#  'for',
#  'second',
#  'mr',
#  'dursley',
#  'realize',
#  'seen',
#  'jerked',
#  'head',
#  'around',
#  'look',
#  'there',
#  'tabby',
#  'cat',
#  'standing',
#  'corner',
#  'privet',
#  'drive',
#  'map',
#  'sight',
#  'what',
#  'could',
#  'thinking',
#  'it',
#  'must',
#  'trick',
#  'light',
#  'mr',
#  'dursley',
#  'blinked',
#  'stared',
#  'cat',
#  'it',
#  'stared',
#  'back',
#  'as',
#  'mr',
#  'dursley',
#  'drove',
#  'around',
#  'corner',
#  'road',
#  'watched',
#  'cat',
#  'mirror',
#  'it',
#  'reading',
#  'sign',
#  'said',
#  'privet',
#  'drive',
#  'looking',
#  'sign',
#  'cats',
#  'read',
#  'maps',
#  'signs',
#  'mr',
#  'dursley',
#  'gave',
#  'little',
#  'shake',
#  'put',
#  'cat',
#  'mind',
#  'as',
#  'drove',
#  'toward',
#  'town',
#  'thought',
#  'nothing',
#  'except',
#  'large',
#  'order',
#  'drills',
#  'hoping',
#  'get',
#  'day',
#  'but',
#  'edge',
#  'town',
#  'drills',
#  'driven',
#  'mind',
#  'something',
#  'else',
#  'as',
#  'sat',
#  'usual',
#  'morning',
#  'traffic',
#  'jam',
#  'help',
#  'noticing',
#  'seemed',
#  'lot',
#  'strangely',
#  'dressed',
#  'people',
#  'people',
#  'cloaks',
#  'mr',
#  'dursley',
#  'bear',
#  'people',
#  'dressed',
#  'funny',
#  'clothes',
#  'getups',
#  'saw',
#  'young',
#  'people',
#  'he',
#  'supposed',
#  'stupid',
#  'new',
#  'fashion',
#  'he',
#  'drummed',
#  'fingers',
#  'steering',
#  'wheel',
#  'eyes',
#  'fell',
#  'huddle',
#  'weirdos',
#  'standing',
#  'quite',
#  'close',
#  'they',
#  'whispering',
#  'excitedly',
#  'together',
#  'mr',
#  'dursley',
#  'enraged',
#  'see',
#  'couple',
#  'young',
#  'man',
#  'older',
#  'wearing',
#  'emerald',
#  'green',
#  'cloak',
#  'the',
#  'nerve',
#  'but',
#  'struck',
#  'mr',
#  'dursley',
#  'probably',
#  'silly',
#  'stunt',
#  'people',
#  'obviously',
#  'collecting',
#  'something',
#  'yes',
#  'would',
#  'the',
#  'traffic',
#  'moved',
#  'minutes',
#  'later',
#  'mr',
#  'dursley',
#  'arrived',
#  'grunnings',
#  'parking',
#  'lot',
#  'mind',
#  'back',
#  'drills',
#  'mr',
#  'dursley',
#  'always',
#  'sat',
#  'back',
#  'window',
#  'office',
#  'ninth',
#  'floor',
#  'if',
#  'might',
#  'found',
#  'harder',
#  'concentrate',
#  'drills',
#  'morning',
#  'he',
#  'see',
#  'owls',
#  'swoop',
#  'ing',
#  'past',
#  'broad',
#  'daylight',
#  'though',
#  'people',
#  'street',
#  'pointed',
#  'gazed',
#  'open',
#  'mouthed',
#  'owl',
#  'owl',
#  'sped',
#  'overhead',
#  'most',
#  'never',
#  'seen',
#  'owl',
#  'even',
#  'nighttime',
#  'mr',
#  'dursley',
#  'however',
#  'perfectly',
#  'normal',
#  'owl',
#  'free',
#  'morning',
#  'he',
#  'yelled',
#  'five',
#  'different',
#  'people',
#  'he',
#  'made',
#  'several',
#  'important',
#  'telephone',
#  'calls',
#  'shouted',
#  'bit',
#  'he',
#  'good',
#  'mood',
#  'lunchtime',
#  'thought',
#  'stretch',
#  'legs',
#  'walk',
#  'across',
#  'road',
#  'buy',
#  'bun',
#  'bakery',
#  'he',
#  'forgotten',
#  'people',
#  'cloaks',
#  'passed',
#  'group',
#  'next',
#  'baker',
#  'he',
#  'eyed',
#  'angrily',
#  'passed',
#  'he',
#  'know',
#  'made',
#  'uneasy',
#  'this',
#  'bunch',
#  'whispering',
#  'excitedly',
#  'see',
#  'single',
#  'collecting',
#  'tin',
#  'it',
#  'way',
#  'back',
#  'past',
#  'clutching',
#  'large',
#  'doughnut',
#  'bag',
#  'caught',
#  'words',
#  'saying',
#  'the',
#  'potters',
#  'right',
#  'i',
#  'heard',
#  'yes',
#  'son',
#  'harry',
#  'mr',
#  'dursley',
#  'stopped',
#  'dead',
#  'fear',
#  'flooded',
#  'he',
#  'looked',
#  'back',
#  'whisperers',
#  'wanted',
#  'say',
#  'something',
#  'thought',
#  'better',
#  'he',
#  'dashed',
#  'back',
#  'across',
#  'road',
#  'hurried',
#  'office',
#  'snapped',
#  'secretary',
#  'disturb',
#  'seized',
#  'telephone',
#  'almost',
#  'finished',
#  'dialing',
#  'home',
#  'number',
#  'changed',
#  'mind',
#  'he',
#  'put',
#  'receiver',
#  'back',
#  'stroked',
#  'mustache',
#  'thinking',
#  'stupid',
#  'potter',
#  'unusual',
#  'name',
#  'he',
#  'sure',
#  'lots',
#  'people',
#  'called',
#  'potter',
#  'son',
#  'called',
#  'harry',
#  'come',
#  'think',
#  'even',
#  'sure',
#  'nephew',
#  'called',
#  'harry',
#  'he',
#  'never',
#  'even',
#  'seen',
#  'boy',
#  'it',
#  'might',
#  'harvey',
#  'or',
#  'harold',
#  'there',
#  'point',
#  'worrying',
#  'mrs',
#  'dursley',
#  'always',
#  'got',
#  'upset',
#  'mention',
#  'sister',
#  'he',
#  'blame',
#  'sister',
#  'like',
#  'people',
#  'cloaks',
#  'he',
#  'found',
#  'lot',
#  'harder',
#  'concentrate',
#  'drills',
#  'afternoon',
#  'left',
#  'building',
#  'five',
#  'clock',
#  'still',
#  'worried',
#  'walked',
#  'straight',
#  'someone',
#  'outside',
#  'door',
#  'sorry',
#  'grunted',
#  'tiny',
#  'old',
#  'man',
#  'stumbled',
#  'almost',
#  'fell',
#  'it',
#  'seconds',
#  'mr',
#  'dursley',
#  'realized',
#  'man',
#  'wearing',
#  'violet',
#  'cloak',
#  'he',
#  'seem',
#  'upset',
#  'almost',
#  'knocked',
#  'ground',
#  'on',
#  'contrary',
#  'face',
#  'split',
#  'wide',
#  'smile',
#  'said',
#  'squeaky',
#  'voice',
#  'made',
#  'passersby',
#  'stare',
#  'don',
#  'sorry',
#  'dear',
#  'sir',
#  'nothing',
#  'could',
#  'upset',
#  'today',
#  'rejoice',
#  'you',
#  'know',
#  'who',
#  'gone',
#  'last',
#  'even',
#  'muggles',
#  'like',
#  'celebrating',
#  'happy',
#  'happy',
#  'day',
#  'and',
#  'old',
#  'man',
#  'hugged',
#  'mr',
#  'dursley',
#  'around',
#  'middle',
#  'walked',
#  'mr',
#  'dursley',
#  'stood',
#  'rooted',
#  'spot',
#  'he',
#  'hugged',
#  'complete',
#  'stranger',
#  'he',
#  'also',
#  'thought',
#  'called',
#  'muggle',
#  'whatever',
#  'he',
#  'rattled',
#  'he',
#  'hurried',
#  'car',
#  'set',
#  'home',
#  'hoping',
#  'imagining',
#  'things',
#  'never',
#  'hoped',
#  'approve',
#  'imagination',
#  'as',
#  'pulled',
#  'driveway',
#  'number',
#  'four',
#  'first',
#  'thing',
#  'saw',
#  'improve',
#  'mood',
#  'tabby',
#  'cat',
#  'spotted',
#  'morning',
#  'it',
#  'sitting',
#  'garden',
#  'wall',
#  'he',
#  'sure',
#  'one',
#  'markings',
#  'around',
#  'eyes',
#  'shoo',
#  'said',
#  'mr',
#  'dursley',
#  'loudly',
#  'the',
#  'cat',
#  'move',
#  'it',
#  'gave',
#  'stern',
#  'look',
#  'was',
#  'normal',
#  'cat',
#  'behavior',
#  'mr',
#  'dursley',
#  'wondered',
#  'trying',
#  'pull',
#  'together',
#  'let',
#  'house',
#  'he',
#  'still',
#  'determined',
#  'mention',
#  'anything',
#  'wife',
#  'mrs',
#  'dursley',
#  'nice',
#  'normal',
#  'day',
#  'she',
#  'told',
#  'dinner',
#  'mrs',
#  'next',
#  'door',
#  'problems',
#  'daughter',
#  'dudley',
#  'learned',
#  'new',
#  'word',
#  'won',
#  'mr',
#  'dursley',
#  'tried',
#  'act',
#  'normally',
#  'when',
#  'dudley',
#  'put',
#  'bed',
#  'went',
#  'living',
#  'room',
#  'time',
#  'catch',
#  'last',
#  'report',
#  'evening',
#  'news',
#  'and',
#  'finally',
#  'bird',
#  'watchers',
#  'everywhere',
#  'reported',
#  'nation',
#  'owls',
#  'behaving',
#  'unusually',
#  'today',
#  'although',
#  'owls',
#  'normally',
#  'hunt',
#  'night',
#  'hardly',
#  'ever',
#  'seen',
#  'daylight',
#  'hundreds',
#  'sightings',
#  'birds',
#  'flying',
#  'every',
#  'direction',
#  'since',
#  'sunrise',
#  'experts',
#  'unable',
#  'explain',
#  'owls',
#  'suddenly',
#  'changed',
#  'sleeping',
#  'pattern',
#  'the',
#  'newscaster',
#  'allowed',
#  'grin',
#  'most',
#  'mysterious',
#  'and',
#  'jim',
#  'mcguffin',
#  'weather',
#  'going',
#  'showers',
#  'owls',
#  'tonight',
#  'jim',
#  'well',
#  'ted',
#  'said',
#  'weatherman',
#  'i',
#  'know',
#  'owls',
#  'acting',
#  'oddly',
#  'today',
#  'viewers',
#  'far',
#  'apart',
#  'kent',
#  'yorkshire',
#  'dundee',
#  'phoning',
#  'tell',
#  'instead',
#  'rain',
#  'i',
#  'promised',
#  'yesterday',
#  'downpour',
#  'shooting',
#  'stars',
#  'perhaps',
#  'people',
#  'celebrating',
#  'bonfire',
#  'night',
#  'early',
#  'next',
#  'week',
#  'folks',
#  'but',
#  'i',
#  'promise',
#  'wet',
#  'night',
#  'tonight',
#  'mr',
#  'dursley',
#  'sat',
#  'frozen',
#  'armchair',
#  'shooting',
#  'stars',
#  'britain',
#  'owls',
#  'flying',
#  'daylight',
#  'mysterious',
#  'people',
#  'cloaks',
#  'place',
#  'and',
#  'whisper',
#  'whisper',
#  'potters',
#  'mrs',
#  'dursley',
#  'came',
#  'living',
#  'room',
#  'carrying',
#  'two',
#  'cups',
#  'tea',
#  'it',
#  'good',
#  'he',
#  'say',
#  'something',
#  'he',
#  'cleared',
#  'throat',
#  'nervously',
#  'er',
#  'petunia',
#  'dear',
#  'heard',
#  'sister',
#  'lately',
#  'as',
#  'expected',
#  'mrs',
#  'dursley',
#  'looked',
#  'shocked',
#  'angry',
#  'after',
#  'normally',
#  'pretended',
#  'sister',
#  'no',
#  'said',
#  'sharply',
#  'why',
#  'funny',
#  'stuff',
#  'news',
#  'mr',
#  'dursley',
#  'mumbled',
#  'owls',
#  'shooting',
#  'stars',
#  'lot',
#  'funny',
#  'looking',
#  'people',
#  'town',
#  'today',
#  'so',
#  'snapped',
#  'mrs',
#  'dursley',
#  'well',
#  'i',
#  'thought',
#  'maybe',
#  'something',
#  'know',
#  'crowd',
#  'mrs',
#  ...]

# %%
vocab = set(word_tokens)
char_to_int = dict((c,i) for i,c in enumerate(vocab))
int_to_char = dict((i,c) for i,c in enumerate(vocab))

# %%
X = np.array([], dtype=np.float).reshape(0,4)
Y = np.array([])
Xwords=[]
Ywords=[]
window_size = 2
for i, word in enumerate(word_tokens):
    Xsub=np.zeros(2*window_size)
    Xsubwords=[]
    isetvalue=0
    for icontext in range(max(i-window_size,0), min(i+window_size, len(word_tokens)-1)+1):
        if icontext!=i:
            Xsub[isetvalue]=char_to_int[word_tokens[icontext]]
            Xsubwords.append(word_tokens[icontext])
            isetvalue=isetvalue+1
    X=np.vstack([X, Xsub])
    Xwords.append(Xsubwords)
    Y=np.append(Y,char_to_int[word])
    Ywords.append(word)

# %%
print([X[0][1]])
print([Y[0]])
# Out:
# [5482.0]
# [1947.0]

# %%
embedding_dim=100
vocab_size=len(vocab)
cbowNN = keras.Sequential([
    layers.Embedding(vocab_size, embedding_dim),
    layers.GlobalAveragePooling1D(),
    layers.Dense(vocab_size, activation='softmax')
])

# %%
cbowNN.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = cbowNN.fit(X, Y,epochs=10)
# Out:
# Train on 45231 samples
# Epoch 1/10
# 45231/45231 [==============================] - 22s 483us/sample - loss: 7.5646 - accuracy: 0.0307
# Epoch 2/10
# 45231/45231 [==============================] - 22s 480us/sample - loss: 7.2158 - accuracy: 0.0397
# Epoch 3/10
# 45231/45231 [==============================] - 22s 482us/sample - loss: 7.0520 - accuracy: 0.0513
# Epoch 4/10
# 45231/45231 [==============================] - 23s 503us/sample - loss: 6.8633 - accuracy: 0.0598
# Epoch 5/10
# 45231/45231 [==============================] - 23s 513us/sample - loss: 6.6308 - accuracy: 0.0694
# Epoch 6/10
# 45231/45231 [==============================] - 22s 494us/sample - loss: 6.3545 - accuracy: 0.0814
# Epoch 7/10
# 45231/45231 [==============================] - 22s 495us/sample - loss: 6.0483 - accuracy: 0.0955
# Epoch 8/10
# 45231/45231 [==============================] - 23s 501us/sample - loss: 5.7261 - accuracy: 0.1134
# Epoch 9/10
# 45231/45231 [==============================] - 23s 504us/sample - loss: 5.3974 - accuracy: 0.1321
# Epoch 10/10
# 45231/45231 [==============================] - 23s 510us/sample - loss: 5.0706 - accuracy: 0.1545

# %%
char_to_int["harry"]
# Out:
# 1947

# %%
char_to_int["potter"]
# Out:
# 4788

# %%
int_to_char[1947]
# Out:
# 'harry'

# %%
int_to_char[3]
# Out:
# 'trapdoor'

# %%
from numpy.linalg import norm
e = cbowNN.layers[0]
a=e(tf.constant(char_to_int[])).numpy()
b=e(tf.constant(char_to_int[]).numpy()
np.dot(a,b)/norm(a)/norm(b)
# Out:
# -0.20731312

# %%
e.get_weights()[0][4788]
# Out:
# array([ 0.01745052,  0.54161495,  0.44928062, -0.06946293, -0.3814767 ,
#         0.06661142,  0.19729066, -0.21879932, -1.1775899 ,  0.07631734,
#        -0.26293132,  0.41576278, -0.04245192, -0.40860093, -0.90867996,
#         0.3284736 , -0.36940235,  0.49158996, -0.2378846 ,  0.23236126,
#         0.3277295 , -0.32228482, -0.48528573, -0.11750998, -0.22386056,
#         0.4585344 , -0.23257151,  0.5125476 , -0.62019193, -0.676352  ,
#        -0.49035376, -0.26184666, -0.46588188, -0.44267207, -0.61373013,
#        -0.69485587, -0.5654698 ,  0.448015  , -0.11497999, -0.82175934,
#        -0.17412528,  0.80889654,  0.4535465 , -0.04663071, -0.8691258 ,
#        -0.16155294,  0.30515635,  1.0820371 ,  0.7889312 ,  0.6587616 ,
#        -0.28671873,  0.59912026, -0.19276829,  0.10982078, -0.08996927,
#        -0.5173971 , -0.691293  ,  0.6874281 ,  0.16498521,  0.305381  ,
#         0.04232306, -0.04907692, -0.6132872 ,  0.75853306, -0.18022999,
#        -0.74155426, -0.54906267, -0.44622275, -0.5036917 , -0.00380181,
#         0.6199248 , -0.9356968 , -0.23008497,  0.51774293, -0.4732884 ,
#        -0.512716  ,  0.51517725, -0.10544002,  0.2727575 ,  0.25054368,
#         0.40498662,  0.5014704 ,  0.5213145 ,  0.35005432, -0.6667936 ,
#         0.13805819, -0.4739256 , -0.0327877 ,  0.54545915, -0.33540034,
#         0.9364574 ,  0.26989242,  0.62259835, -0.17193167,  0.80391943,
#         0.55492485, -0.3565871 , -0.22338158,  0.64064145,  0.25793317],
#       dtype=float32)

# %%
cbowNN.predict(tf.constant([3767]))
# Out:
# array([[2.2948307e-22, 3.2295737e-35, 4.3348098e-26, ..., 1.5308596e-27,
#         1.0985353e-19, 2.6982707e-24]], dtype=float32)

# %%
np.argmax(cbowNN.predict(tf.constant([3767]))[0])
# Out:
# 4196

# %%
len(cbowNN.predict(tf.constant([49]))[0])

# %%
np.argsort(cbowNN.predict(tf.constant([1947]))[0])
# Out:
# array([2403, 2296, 3256, ..., 1630,  651, 4788])

# %%
words
# Out:
# ['harry',
#  'potter',
#  'and',
#  'the',
#  'stone',
#  'chapter',
#  'one',
#  'the',
#  'boy',
#  'who',
#  'lived',
#  'and',
#  'of',
#  'number',
#  'privet',
#  'were',
#  'proud',
#  'to',
#  'say',
#  'that',
#  'they',
#  'were',
#  'perfectly',
#  'thank',
#  'you',
#  'very',
#  'they',
#  'were',
#  'the',
#  'last',
#  'people',
#  'expect',
#  'to',
#  'be',
#  'involved',
#  'in',
#  'anything',
#  'strange',
#  'or',
#  'because',
#  'they',
#  'just',
#  'hold',
#  'with',
#  'such',
#  'dursley',
#  'was',
#  'the',
#  'director',
#  'of',
#  'firm',
#  'called',
#  'which',
#  'made',
#  'he',
#  'was',
#  'beefy',
#  'man',
#  'with',
#  'hardly',
#  'any',
#  'although',
#  'he',
#  'did',
#  'have',
#  'very',
#  'large',
#  'dursley',
#  'was',
#  'thin',
#  'and',
#  'blonde',
#  'and',
#  'had',
#  'nearly',
#  'twice',
#  'the',
#  'usual',
#  'amount',
#  'of',
#  'which',
#  'came',
#  'in',
#  'very',
#  'useful',
#  'as',
#  'she',
#  'spent',
#  'so',
#  'much',
#  'of',
#  'her',
#  'time',
#  'craning',
#  'over',
#  'garden',
#  'spying',
#  'on',
#  'the',
#  'the',
#  'dursleys',
#  'had',
#  'small',
#  'son',
#  'called',
#  'dudley',
#  'and',
#  'in',
#  'their',
#  'opinion',
#  'there',
#  'was',
#  'no',
#  'finer',
#  'boy',
#  'the',
#  'dursleys',
#  'had',
#  'everything',
#  'they',
#  'but',
#  'they',
#  'also',
#  'had',
#  'and',
#  'their',
#  'greatest',
#  'fear',
#  'was',
#  'that',
#  'somebody',
#  'would',
#  'discover',
#  'they',
#  'think',
#  'they',
#  'could',
#  'bear',
#  'it',
#  'if',
#  'anyone',
#  'found',
#  'out',
#  'about',
#  'the',
#  'potter',
#  'was',
#  'but',
#  'they',
#  'met',
#  'for',
#  'several',
#  'in',
#  'dursley',
#  'pretended',
#  'she',
#  'have',
#  'because',
#  'her',
#  'sister',
#  'and',
#  'her',
#  'husband',
#  'were',
#  'as',
#  'undursleyish',
#  'as',
#  'it',
#  'was',
#  'possible',
#  'to',
#  'the',
#  'dursleys',
#  'shuddered',
#  'to',
#  'think',
#  'what',
#  'the',
#  'neighbors',
#  'would',
#  'say',
#  'if',
#  'the',
#  'potters',
#  'arrived',
#  'in',
#  'the',
#  'the',
#  'dursleys',
#  'knew',
#  'that',
#  'the',
#  'potters',
#  'had',
#  'small',
#  'but',
#  'they',
#  'had',
#  'never',
#  'even',
#  'seen',
#  'this',
#  'boy',
#  'was',
#  'another',
#  'good',
#  'reason',
#  'for',
#  'keeping',
#  'the',
#  'potters',
#  'they',
#  'want',
#  'dudley',
#  'mixing',
#  'with',
#  'child',
#  'like',
#  'when',
#  'and',
#  'dursley',
#  'woke',
#  'up',
#  'on',
#  'the',
#  'gray',
#  'tuesday',
#  'our',
#  'story',
#  'there',
#  'was',
#  'nothing',
#  'about',
#  'the',
#  'cloudy',
#  'sky',
#  'outside',
#  'to',
#  'suggest',
#  'that',
#  'strange',
#  'and',
#  'mysterious',
#  'things',
#  'would',
#  'soon',
#  'be',
#  'happening',
#  'all',
#  'over',
#  'the',
#  'dursley',
#  'hummed',
#  'as',
#  'he',
#  'picked',
#  'out',
#  'his',
#  'most',
#  'boring',
#  'tie',
#  'for',
#  'and',
#  'dursley',
#  'gossiped',
#  'away',
#  'happily',
#  'as',
#  'she',
#  'wrestled',
#  'screaming',
#  'dudley',
#  'into',
#  'his',
#  'high',
#  'none',
#  'of',
#  'them',
#  'noticed',
#  'tawny',
#  'owl',
#  'flutter',
#  'past',
#  'the',
#  'at',
#  'half',
#  'past',
#  'dursley',
#  'picked',
#  'up',
#  'his',
#  'pecked',
#  'dursley',
#  'on',
#  'the',
#  'and',
#  'tried',
#  'to',
#  'kiss',
#  'dudley',
#  'but',
#  'because',
#  'dudley',
#  'was',
#  'now',
#  'having',
#  'tantrum',
#  'and',
#  'throwing',
#  'his',
#  'cereal',
#  'at',
#  'the',
#  'chortled',
#  'dursley',
#  'as',
#  'he',
#  'left',
#  'the',
#  'he',
#  'got',
#  'into',
#  'his',
#  'car',
#  'and',
#  'backed',
#  'out',
#  'of',
#  'number',
#  'it',
#  'was',
#  'on',
#  'the',
#  'corner',
#  'of',
#  'the',
#  'street',
#  'that',
#  'he',
#  'noticed',
#  'the',
#  'first',
#  'sign',
#  'of',
#  'something',
#  'peculiar',
#  'cat',
#  'reading',
#  'for',
#  'dursley',
#  'realize',
#  'what',
#  'he',
#  'had',
#  'seen',
#  'then',
#  'he',
#  'jerked',
#  'his',
#  'head',
#  'around',
#  'to',
#  'look',
#  'there',
#  'was',
#  'tabby',
#  'cat',
#  'standing',
#  'on',
#  'the',
#  'corner',
#  'of',
#  'privet',
#  'but',
#  'there',
#  'map',
#  'in',
#  'what',
#  'could',
#  'he',
#  'have',
#  'been',
#  'thinking',
#  'it',
#  'must',
#  'have',
#  'been',
#  'trick',
#  'of',
#  'the',
#  'dursley',
#  'blinked',
#  'and',
#  'stared',
#  'at',
#  'the',
#  'it',
#  'stared',
#  'as',
#  'dursley',
#  'drove',
#  'around',
#  'the',
#  'corner',
#  'and',
#  'up',
#  'the',
#  'he',
#  'watched',
#  'the',
#  'cat',
#  'in',
#  'his',
#  'it',
#  'was',
#  'now',
#  'reading',
#  'the',
#  'sign',
#  'that',
#  'said',
#  'privet',
#  'drive',
#  'looking',
#  'at',
#  'the',
#  'cats',
#  'read',
#  'maps',
#  'or',
#  'dursley',
#  'gave',
#  'himself',
#  'little',
#  'shake',
#  'and',
#  'put',
#  'the',
#  'cat',
#  'out',
#  'of',
#  'his',
#  'as',
#  'he',
#  'drove',
#  'toward',
#  'town',
#  'he',
#  'thought',
#  'of',
#  'nothing',
#  'except',
#  'large',
#  'order',
#  'of',
#  'drills',
#  'he',
#  'was',
#  'hoping',
#  'to',
#  'get',
#  'that',
#  'but',
#  'on',
#  'the',
#  'edge',
#  'of',
#  'drills',
#  'were',
#  'driven',
#  'out',
#  'of',
#  'his',
#  'mind',
#  'by',
#  'something',
#  'as',
#  'he',
#  'sat',
#  'in',
#  'the',
#  'usual',
#  'morning',
#  'traffic',
#  'he',
#  'help',
#  'noticing',
#  'that',
#  'there',
#  'seemed',
#  'to',
#  'be',
#  'lot',
#  'of',
#  'strangely',
#  'dressed',
#  'people',
#  'people',
#  'in',
#  'dursley',
#  'bear',
#  'people',
#  'who',
#  'dressed',
#  'in',
#  'funny',
#  'clothes',
#  'the',
#  'getups',
#  'you',
#  'saw',
#  'on',
#  'young',
#  'he',
#  'supposed',
#  'this',
#  'was',
#  'some',
#  'stupid',
#  'new',
#  'he',
#  'drummed',
#  'his',
#  'fingers',
#  'on',
#  'the',
#  'steering',
#  'wheel',
#  'and',
#  'his',
#  'eyes',
#  'fell',
#  'on',
#  'huddle',
#  'of',
#  'these',
#  'weirdos',
#  'standing',
#  'quite',
#  'close',
#  'they',
#  'were',
#  'whispering',
#  'excitedly',
#  'dursley',
#  'was',
#  'enraged',
#  'to',
#  'see',
#  'that',
#  'couple',
#  'of',
#  'them',
#  'young',
#  'at',
#  'that',
#  'man',
#  'had',
#  'to',
#  'be',
#  'older',
#  'than',
#  'he',
#  'and',
#  'wearing',
#  'an',
#  'the',
#  'nerve',
#  'of',
#  'but',
#  'then',
#  'it',
#  'struck',
#  'dursley',
#  'that',
#  'this',
#  'was',
#  'probably',
#  'some',
#  'silly',
#  'stunt',
#  'these',
#  'people',
#  'were',
#  'obviously',
#  'collecting',
#  'for',
#  'that',
#  'would',
#  'be',
#  'the',
#  'traffic',
#  'moved',
#  'on',
#  'and',
#  'few',
#  'minutes',
#  'dursley',
#  'arrived',
#  'in',
#  'the',
#  'grunnings',
#  'parking',
#  'his',
#  'mind',
#  'back',
#  'on',
#  'dursley',
#  'always',
#  'sat',
#  'with',
#  'his',
#  'back',
#  'to',
#  'the',
#  'window',
#  'in',
#  'his',
#  'office',
#  'on',
#  'the',
#  'ninth',
#  'if',
#  'he',
#  'he',
#  'might',
#  'have',
#  'found',
#  'it',
#  'harder',
#  'to',
#  'concentrate',
#  'on',
#  'drills',
#  'that',
#  'he',
#  'see',
#  'the',
#  'owls',
#  'swoop',
#  'ing',
#  'past',
#  'in',
#  'broad',
#  'though',
#  'people',
#  'down',
#  'in',
#  'the',
#  'street',
#  'they',
#  'pointed',
#  'and',
#  'gazed',
#  'mouthed',
#  'as',
#  'owl',
#  'after',
#  'owl',
#  'sped',
#  'most',
#  'of',
#  'them',
#  'had',
#  'never',
#  'seen',
#  'an',
#  'owl',
#  'even',
#  'at',
#  'had',
#  'perfectly',
#  'he',
#  'yelled',
#  'at',
#  'five',
#  'different',
#  'he',
#  'made',
#  'several',
#  'important',
#  'telephone',
#  'calls',
#  'and',
#  'shouted',
#  'bit',
#  'he',
#  'was',
#  'in',
#  'very',
#  'good',
#  'mood',
#  'until',
#  'when',
#  'he',
#  'thought',
#  'stretch',
#  'his',
#  'legs',
#  'and',
#  'walk',
#  'across',
#  'the',
#  'road',
#  'to',
#  'buy',
#  'himself',
#  'bun',
#  'from',
#  'the',
#  'forgotten',
#  'all',
#  'about',
#  'the',
#  'people',
#  'in',
#  'cloaks',
#  'until',
#  'he',
#  'passed',
#  'group',
#  'of',
#  'them',
#  'next',
#  'to',
#  'the',
#  'he',
#  'eyed',
#  'them',
#  'angrily',
#  'as',
#  'he',
#  'he',
#  'know',
#  'but',
#  'they',
#  'made',
#  'him',
#  'this',
#  'bunch',
#  'were',
#  'whispering',
#  'and',
#  'he',
#  'see',
#  'single',
#  'collecting',
#  'it',
#  'was',
#  'on',
#  'his',
#  'way',
#  'back',
#  'past',
#  'clutching',
#  'large',
#  'doughnut',
#  'in',
#  'that',
#  'he',
#  'caught',
#  'few',
#  'words',
#  'of',
#  'what',
#  'they',
#  'were',
#  'what',
#  'heard',
#  'their',
#  'dursley',
#  'stopped',
#  'fear',
#  'flooded',
#  'he',
#  'looked',
#  'back',
#  'at',
#  'the',
#  'whisperers',
#  'as',
#  'if',
#  'he',
#  'wanted',
#  'to',
#  'say',
#  'something',
#  'to',
#  'but',
#  'thought',
#  'better',
#  'of',
#  'he',
#  'dashed',
#  'back',
#  'across',
#  'the',
#  'hurried',
#  'up',
#  'to',
#  'his',
#  'snapped',
#  'at',
#  'his',
#  'secretary',
#  'not',
#  'to',
#  'disturb',
#  'seized',
#  'his',
#  'and',
#  'had',
#  'almost',
#  'finished',
#  'dialing',
#  'his',
#  'home',
#  'number',
#  'when',
#  'he',
#  'changed',
#  'his',
#  'he',
#  'put',
#  'the',
#  'receiver',
#  'back',
#  'down',
#  'and',
#  'stroked',
#  'his',
#  'he',
#  'was',
#  'being',
#  'potter',
#  'such',
#  'an',
#  'unusual',
#  'he',
#  'was',
#  'sure',
#  'there',
#  'were',
#  'lots',
#  'of',
#  'people',
#  'called',
#  'potter',
#  'who',
#  'had',
#  'son',
#  'called',
#  'come',
#  'to',
#  'think',
#  'of',
#  'he',
#  'even',
#  'sure',
#  'his',
#  'nephew',
#  'was',
#  'called',
#  'never',
#  'even',
#  'seen',
#  'the',
#  'it',
#  'might',
#  'have',
#  'been',
#  'or',
#  'there',
#  'was',
#  'no',
#  'point',
#  'in',
#  'worrying',
#  'she',
#  'always',
#  'got',
#  'so',
#  'upset',
#  'at',
#  'any',
#  'mention',
#  'of',
#  'her',
#  'he',
#  'blame',
#  'her',
#  'if',
#  'had',
#  'sister',
#  'like',
#  'but',
#  'all',
#  'the',
#  'those',
#  'people',
#  'in',
#  'he',
#  'found',
#  'it',
#  'lot',
#  'harder',
#  'to',
#  'concentrate',
#  'on',
#  'drills',
#  'that',
#  'afternoon',
#  'and',
#  'when',
#  'he',
#  'left',
#  'the',
#  'building',
#  'at',
#  'five',
#  'he',
#  'was',
#  'still',
#  'so',
#  'worried',
#  'that',
#  'he',
#  'walked',
#  'straight',
#  'into',
#  'someone',
#  'just',
#  'outside',
#  'the',
#  'he',
#  'as',
#  'the',
#  'tiny',
#  'old',
#  'man',
#  'stumbled',
#  'and',
#  'almost',
#  'it',
#  'was',
#  'few',
#  'seconds',
#  'before',
#  'dursley',
#  'realized',
#  'that',
#  'the',
#  'man',
#  'was',
#  'wearing',
#  'violet',
#  'he',
#  'seem',
#  'at',
#  'all',
#  'upset',
#  'at',
#  'being',
#  'almost',
#  'knocked',
#  'to',
#  'the',
#  'on',
#  'the',
#  'his',
#  'face',
#  'split',
#  'into',
#  'wide',
#  'smile',
#  'and',
#  'he',
#  'said',
#  'in',
#  'squeaky',
#  'voice',
#  'that',
#  'made',
#  'passersby',
#  'be',
#  'my',
#  'dear',
#  'for',
#  'nothing',
#  'could',
#  'upset',
#  'me',
#  'for',
#  'has',
#  'gone',
#  'at',
#  'even',
#  'muggles',
#  'like',
#  'yourself',
#  ...]

# %%
for i, word in enumerate(words):
    if word=="ink":
        print(i)
# Out:
# 8548
# 15077

# %%
from sklearn.metrics.pairwise import euclidean_distances

# compute pairwise distance matrix
distance_matrix = euclidean_distances(e.get_weights()[0])
print(distance_matrix.shape)
# Out:
# (5730, 5730)

# %%
# view contextually similar words
similar_words = {search_term: [int_to_char[idx] for idx in distance_matrix[char_to_int[search_term]-1].argsort()[1:6]+1] 
                   for search_term in ['harry', 'potter', 'stone']}

similar_words
# Out:
# {'harry': ['ducking', 'kip', 'catcalling', 'countercurses', 'wings'],
#  'potter': ['isle', 'unbelievable', 'arts', 'signature', 'flailing'],
#  'stone': ['shake', 'excitement', 'side', 'staggerin', 'kept']}
